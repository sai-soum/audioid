# %%
import os
import sys
import glob
import resampy
import librosa
import numpy as np
import scipy.signal
import librosa.display
import soundfile as sf
import pickle
import matplotlib.pyplot as plt
from skimage.feature import peak_local_max
import random

# %% [markdown]
# Functions for the system:

# %%
#this function picks peaks above a given threshold from the stft of an audio file
def peak_picking(
    audio_file : str,
    sample_rate : int = 22050,
    n_fft : int = 2048, 
    hop_length : int = 256,
    win_length : int = None,
    window : str = 'hann',
    peak_distance : int = 24,
    threshold_abs : float = -60,
    
) -> list:
#read the audio file
    x, sr = sf.read(audio_file)
#standardize all audio to 22.5KHz
    if sr != sample_rate:
            x = resampy.resample(x, sr, sample_rate)
#normalise the audio
    x /= np.max(np.abs(x))
#calculate stft
    D = librosa.stft(
            x, 
            n_fft=n_fft, 
            hop_length=hop_length,
            win_length=win_length,
            window=window
        )
#calculate magnitude
    X = np.abs(D)
    X /= np.max(X)

    
#find peaks in the stft based on the threshold
    peaks = peak_local_max(
                        X, 
                        min_distance=peak_distance, 
                        threshold_abs=threshold_abs
                    )
#sort the peaks in the time axis
    peaks = peaks[np.argsort(peaks[:, 1])]

    return peaks

# %%
#this function creates hashes from the peaks
def generate_hashes(
           audio_file: str,
           max_peaks : int = 24 ,
           target_zone_freq : int = 256,
           target_zone_time : int = 128,
           
        
):

    filename = os.path.basename(audio_file).replace(".wav", "")
    peaks = peak_picking(audio_file)
    hashes = []
    # iterate over each peak
    for n in range(peaks.shape[0]):
        anchor_peaks = peaks[n,:]

        # iterate over all peaks to find peaks within the target zone
        peaks_in_target_zone = 0
        for i in range(peaks.shape[0]):
            target_peaks = peaks[i,:] 
            # find peaks within the target zone to generate hashes
            if ((target_peaks[0] < anchor_peaks[0] + target_zone_freq) and (target_peaks[0] > anchor_peaks[0] - target_zone_freq) and 
                (target_peaks[1] < anchor_peaks[1] + target_zone_time) and (target_peaks[1] > anchor_peaks[1] + 1) and 
                not np.array_equal(target_peaks, anchor_peaks)):
                hashes.append({
                    "hash" : (anchor_peaks[0], target_peaks[0], target_peaks[1] - anchor_peaks[1]),
                            # (anchor_peaks freq, target_peaks freqs, time difference)
                    "song" : filename,
                    "timestep" : anchor_peaks[1]
                })
                peaks_in_target_zone += 1
            if peaks_in_target_zone > max_peaks: break

    if len(hashes) < 1:
        print(f"No hashes found. {filename}")

    return hashes

# %%
#this functions generates fingerprints for the database
def db_fingerprint(audiodata_dir : str,
                   fp_dir : str = "fingerprints.pkl",
                   
):


    audio_files = sorted(glob.glob(os.path.join(audiodata_dir, "*.wav")))
 
    db_songs_hashes = []

    for audio_file in audio_files:
        db_songs_hashes.append(generate_hashes(audio_file))


    db_songs = []

    # structure the list of songs
    # create a list of dicts, which the song id, and inverted lists
    for db_song in db_songs_hashes:
        db_song_inv_lists = {}
        if len(db_song) < 1:
            print(db_song)
        song_id = db_song[0]["song"]
        
        for db_song_hash in db_song:
            if db_song_hash["hash"] not in db_song_inv_lists:
                db_song_inv_lists[db_song_hash["hash"]] = [db_song_hash["timestep"]]
            else:
                db_song_inv_lists[db_song_hash["hash"]] += db_song_hash["timestep"]
        db_songs.append({
            "song_id" : song_id,
            "inverted_lists" : db_song_inv_lists
        })

    # save list of database song hashes to disk
    with open(fp_dir, 'wb') as f:
        pickle.dump(db_songs, f)

# %%
#this function is used to find all the possible matches for the query
def find_matches(
      query_hashes : list,
      db_fingerprints: list
  ):
 
    matches = {}
    # iterate over each fingerprint in the database
    for db_fingerprint in db_fingerprints:
        fingerprint_id = db_fingerprint["song_id"]
        inverted_lists = db_fingerprint["inverted_lists"]
        match_timesteps = {}
        for q_hash in query_hashes: # each hash is a query
            if q_hash["hash"] in inverted_lists: # check if hash is in inverted lists
                for timestep in inverted_lists[q_hash["hash"]]:
                    shifted = timestep - q_hash["timestep"]
                    if shifted not in match_timesteps:
                        match_timesteps[shifted] = 1
                    else:
                        match_timesteps[shifted] += 1

        if len(match_timesteps.values()) > 0:
            # return the max value of the mathcing function histogram
            matches[fingerprint_id] = max(match_timesteps.values())

    return matches

# %%
#this function finda the matches
def audioid(
    query_audio: str,
    fingerprint_database: str = "fingerprints.pkl",
    ):
#generate fingerprint for the query
    query_hash = generate_hashes(query_audio)
    #print("\ngenerating query hashes..")
#load back the fingerprints for the database
    with open(fingerprint_database, 'rb') as f:
        db_fingerprints = pickle.load(f)
    
    query_match = [] # we will store all matches here
    #print("Finding matches...")
    query_match.append(find_matches(query_hash, db_fingerprints))

    return query_match

# %%
#This function finda the top match for a query
def top_match_(
    q_audio : str
):
    matches = audioid(q_audio)
    max_val = 0
    max_key = None
    #Check if the song from the database with highest number of matches is the same as the baseline truth
    for k in matches[0].keys():
    #print(matches[0][k])
        if max_val < matches[0][k]:
            max_key = k
            max_val = matches[0][k]

    query_id = os.path.basename(q_audio).strip(".wav")

    print("\n for %s top match is %s" %(query_id,max_key))
    return max_key

# %%
#To evaluate the system, we find the number of correct top matches
def accuracy(query_files : list,


):

    
    total_queries = len(query_files)
    correct_matches = 0
    progress = 0
    for audio_file in query_files:
        progress += 1
        print ("\n %s of %s "%(progress,total_queries))
        top_match = top_match_(audio_file)
        
        # get the ground truth song id

        query_id = os.path.basename(audio_file).strip(".wav")
        #print("\n",query_id)
        song_id = query_id.split('-')[0]
        if song_id == top_match:
            correct_matches += 1
        
    
    accuracy = correct_matches/total_queries * 100

    return accuracy

# %% [markdown]
# Get the paths :

# %%
PATH = os.getcwd()
#print(PATH)
database = PATH + '/gtzan/database_recordings/'
query = PATH + '/gtzan/query_recordings/'

# %%
#generate fingerprints for the database
#db_fingerprint(database)
print("Already generated!")
# Out:
# Already generated!

# %%
query_files = sorted(glob.glob(os.path.join(query, "*.wav")))
total_queries = len(query_files)
print(total_queries)
type(query_files)
# Out:
# 213
# list

# %% [markdown]
# Testing the system for a sample query audio:

# %%
#Testing for query_audio

qaudio_file = query + 'classical.00000-snippet-10-0.wav'
match = top_match_(qaudio_file)
#print(match)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-188-fc26e3b6f402> in <module>
#       2
#       3 qaudio_file = query + 'classical.00000-snippet-10-0.wav'
# ----> 4 match = top_match_(qaudio_file)
#       5 #print(match)
#
# <ipython-input-182-403a02a7721d> in top_match_(q_audio)
#       3     q_audio : str
#       4 ):
# ----> 5     matches = audioid(q_audio)
#       6     max_val = 0
#       7     max_key = None
#
# <ipython-input-181-89eeacbc4798> in audioid(query_audio, fingerprint_database)
#       5     ):
#       6 #generate fingerprint for the query
# ----> 7     query_hash = generate_hashes(query_audio)
#       8     #print("\ngenerating query hashes..")
#       9 #load back the fingerprints for the database
#
# <ipython-input-177-6b3a0177ae94> in generate_hashes(audio_file, max_peaks, target_zone_freq, target_zone_time)
#      10
#      11     filename = os.path.basename(audio_file).replace(".wav", "")
# ---> 12     peaks = peak_picking(audio_file,n_fft)
#      13     hashes = []
#      14     # iterate over each peak
#
# NameError: name 'n_fft' is not defined

# %% [markdown]
# Evaluate the system:

# %%
#Compute accuracy of the system
query_files = sorted(glob.glob(os.path.join(query_dir, "*.wav")))
accuracy_ = accuracy(query_files)
# Out:
#  1 of 213
#
#  for classical.00000-snippet-10-0 top match is classical.00000
#
#  classical.00000-snippet-10-0
#
#  2 of 213
#
#  for classical.00000-snippet-10-10 top match is classical.00000
#
#  classical.00000-snippet-10-10
#
#  3 of 213
#
#  for classical.00000-snippet-10-20 top match is classical.00000
#
#  classical.00000-snippet-10-20
#
#  4 of 213
#
#  for classical.00003-snippet-10-0 top match is classical.00003
#
#  classical.00003-snippet-10-0
#
#  5 of 213
#
#  for classical.00003-snippet-10-10 top match is classical.00003
#
#  classical.00003-snippet-10-10
#
#  6 of 213
#
#  for classical.00003-snippet-10-20 top match is pop.00036
#
#  classical.00003-snippet-10-20
#
#  7 of 213
#
#  for classical.00004-snippet-10-0 top match is classical.00004
#
#  classical.00004-snippet-10-0
#
#  8 of 213
#
#  for classical.00004-snippet-10-10 top match is classical.00004
#
#  classical.00004-snippet-10-10
#
#  9 of 213
#
#  for classical.00005-snippet-10-0 top match is classical.00005
#
#  classical.00005-snippet-10-0
#
#  10 of 213
#
#  for classical.00005-snippet-10-10 top match is classical.00005
#
#  classical.00005-snippet-10-10
#
#  11 of 213
#
#  for classical.00005-snippet-10-20 top match is classical.00005
#
#  classical.00005-snippet-10-20
#
#  12 of 213
#
#  for classical.00009-snippet-10-0 top match is classical.00009
#
#  classical.00009-snippet-10-0
#
#  13 of 213
#
#  for classical.00009-snippet-10-10 top match is classical.00009
#
#  classical.00009-snippet-10-10
#
#  14 of 213
#
#  for classical.00009-snippet-10-20 top match is classical.00009
#
#  classical.00009-snippet-10-20
#
#  15 of 213
#
#  for classical.00010-snippet-10-0 top match is classical.00010
#
#  classical.00010-snippet-10-0
#
#  16 of 213
#
#  for classical.00010-snippet-10-10 top match is classical.00010
#
#  classical.00010-snippet-10-10
#
#  17 of 213
#
#  for classical.00010-snippet-10-20 top match is classical.00010
#
#  classical.00010-snippet-10-20
#
#  18 of 213
#
#  for classical.00011-snippet-10-0 top match is classical.00011
#
#  classical.00011-snippet-10-0
#
#  19 of 213
#
#  for classical.00011-snippet-10-10 top match is classical.00011
#
#  classical.00011-snippet-10-10
#
#  20 of 213
#
#  for classical.00012-snippet-10-0 top match is classical.00012
#
#  classical.00012-snippet-10-0
#
#  21 of 213
#
#  for classical.00012-snippet-10-10 top match is classical.00012
#
#  classical.00012-snippet-10-10
#
#  22 of 213
#
#  for classical.00012-snippet-10-20 top match is classical.00012
#
#  classical.00012-snippet-10-20
#
#  23 of 213
#
#  for classical.00013-snippet-10-0 top match is classical.00013
#
#  classical.00013-snippet-10-0
#
#  24 of 213
#
#  for classical.00013-snippet-10-10 top match is classical.00013
#
#  classical.00013-snippet-10-10
#
#  25 of 213
#
#  for classical.00013-snippet-10-20 top match is classical.00013
#
#  classical.00013-snippet-10-20
#
#  26 of 213
#
#  for classical.00014-snippet-10-0 top match is classical.00014
#
#  classical.00014-snippet-10-0
#
#  27 of 213
#
#  for classical.00014-snippet-10-10 top match is classical.00014
#
#  classical.00014-snippet-10-10
#
#  28 of 213
#
#  for classical.00014-snippet-10-20 top match is classical.00055
#
#  classical.00014-snippet-10-20
#
#  29 of 213
#
#  for classical.00015-snippet-10-0 top match is classical.00015
#
#  classical.00015-snippet-10-0
#
#  30 of 213
#
#  for classical.00015-snippet-10-10 top match is classical.00015
#
#  classical.00015-snippet-10-10
#
#  31 of 213
#
#  for classical.00015-snippet-10-20 top match is classical.00015
#
#  classical.00015-snippet-10-20
#
#  32 of 213
#
#  for classical.00019-snippet-10-0 top match is classical.00067
#
#  classical.00019-snippet-10-0
#
#  33 of 213
#
#  for classical.00019-snippet-10-10 top match is pop.00065
#
#  classical.00019-snippet-10-10
#
#  34 of 213
#
#  for classical.00019-snippet-10-20 top match is pop.00081
#
#  classical.00019-snippet-10-20
#
#  35 of 213
#
#  for classical.00020-snippet-10-0 top match is classical.00050
#
#  classical.00020-snippet-10-0
#
#  36 of 213
#
#  for classical.00020-snippet-10-10 top match is classical.00020
#
#  classical.00020-snippet-10-10
#
#  37 of 213
#
#  for classical.00020-snippet-10-20 top match is classical.00020
#
#  classical.00020-snippet-10-20
#
#  38 of 213
#
#  for classical.00024-snippet-10-0 top match is classical.00024
#
#  classical.00024-snippet-10-0
#
#  39 of 213
#
#  for classical.00024-snippet-10-10 top match is classical.00024
#
#  classical.00024-snippet-10-10
#
#  40 of 213
#
#  for classical.00024-snippet-10-20 top match is classical.00024
#
#  classical.00024-snippet-10-20
#
#  41 of 213
#
#  for classical.00025-snippet-10-0 top match is classical.00025
#
#  classical.00025-snippet-10-0
#
#  42 of 213
#
#  for classical.00025-snippet-10-10 top match is classical.00025
#
#  classical.00025-snippet-10-10
#
#  43 of 213
#
#  for classical.00025-snippet-10-20 top match is classical.00025
#
#  classical.00025-snippet-10-20
#
#  44 of 213
#
#  for classical.00034-snippet-10-0 top match is classical.00034
#
#  classical.00034-snippet-10-0
#
#  45 of 213
#
#  for classical.00034-snippet-10-10 top match is classical.00034
#
#  classical.00034-snippet-10-10
#
#  46 of 213
#
#  for classical.00034-snippet-10-20 top match is classical.00034
#
#  classical.00034-snippet-10-20
#
#  47 of 213
#
#  for classical.00035-snippet-10-0 top match is classical.00035
#
#  classical.00035-snippet-10-0
#
#  48 of 213
#
#  for classical.00035-snippet-10-10 top match is classical.00035
#
#  classical.00035-snippet-10-10
#
#  49 of 213
#
#  for classical.00035-snippet-10-20 top match is classical.00035
#
#  classical.00035-snippet-10-20
#
#  50 of 213
#
#  for classical.00039-snippet-10-0 top match is classical.00099
#
#  classical.00039-snippet-10-0
#
#  51 of 213
#
#  for classical.00039-snippet-10-10 top match is classical.00039
#
#  classical.00039-snippet-10-10
#
#  52 of 213
#
#  for classical.00039-snippet-10-20 top match is pop.00074
#
#  classical.00039-snippet-10-20
#
#  53 of 213
#
#  for classical.00040-snippet-10-0 top match is classical.00040
#
#  classical.00040-snippet-10-0
#
#  54 of 213
#
#  for classical.00040-snippet-10-10 top match is pop.00037
#
#  classical.00040-snippet-10-10
#
#  55 of 213
#
#  for classical.00044-snippet-10-0 top match is pop.00051
#
#  classical.00044-snippet-10-0
#
#  56 of 213
#
#  for classical.00044-snippet-10-10 top match is classical.00044
#
#  classical.00044-snippet-10-10
#
#  57 of 213
#
#  for classical.00044-snippet-10-20 top match is classical.00036
#
#  classical.00044-snippet-10-20
#
#  58 of 213
#
#  for classical.00045-snippet-10-0 top match is classical.00045
#
#  classical.00045-snippet-10-0
#
#  59 of 213
#
#  for classical.00045-snippet-10-10 top match is classical.00045
#
#  classical.00045-snippet-10-10
#
#  60 of 213
#
#  for classical.00045-snippet-10-20 top match is classical.00045
#
#  classical.00045-snippet-10-20
#
#  61 of 213
#
#  for classical.00049-snippet-10-0 top match is classical.00049
#
#  classical.00049-snippet-10-0
#
#  62 of 213
#
#  for classical.00049-snippet-10-10 top match is classical.00049
#
#  classical.00049-snippet-10-10
#
#  63 of 213
#
#  for classical.00049-snippet-10-20 top match is classical.00049
#
#  classical.00049-snippet-10-20
#
#  64 of 213
#
#  for classical.00050-snippet-10-0 top match is classical.00050
#
#  classical.00050-snippet-10-0
#
#  65 of 213
#
#  for classical.00050-snippet-10-10 top match is classical.00050
#
#  classical.00050-snippet-10-10
#
#  66 of 213
#
#  for classical.00050-snippet-10-20 top match is classical.00050
#
#  classical.00050-snippet-10-20
#
#  67 of 213
#
#  for classical.00054-snippet-10-0 top match is classical.00055
#
#  classical.00054-snippet-10-0
#
#  68 of 213
#
#  for classical.00054-snippet-10-10 top match is classical.00054
#
#  classical.00054-snippet-10-10
#
#  69 of 213
#
#  for classical.00054-snippet-10-20 top match is classical.00054
#
#  classical.00054-snippet-10-20
#
#  70 of 213
#
#  for classical.00055-snippet-10-0 top match is pop.00087
#
#  classical.00055-snippet-10-0
#
#  71 of 213
#
#  for classical.00055-snippet-10-10 top match is classical.00093
#
#  classical.00055-snippet-10-10
#
#  72 of 213
#
#  for classical.00055-snippet-10-20 top match is pop.00050
#
#  classical.00055-snippet-10-20
#
#  73 of 213
#
#  for classical.00059-snippet-10-0 top match is classical.00059
#
#  classical.00059-snippet-10-0
#
#  74 of 213
#
#  for classical.00059-snippet-10-10 top match is classical.00059
#
#  classical.00059-snippet-10-10
#
#  75 of 213
#
#  for classical.00059-snippet-10-20 top match is classical.00059
#
#  classical.00059-snippet-10-20
#
#  76 of 213
#
#  for classical.00060-snippet-10-0 top match is classical.00060
#
#  classical.00060-snippet-10-0
#
#  77 of 213
#
#  for classical.00060-snippet-10-10 top match is classical.00060
#
#  classical.00060-snippet-10-10
#
#  78 of 213
#
#  for classical.00060-snippet-10-20 top match is classical.00060
#
#  classical.00060-snippet-10-20
#
#  79 of 213
#
#  for classical.00064-snippet-10-0 top match is classical.00064
#
#  classical.00064-snippet-10-0
#
#  80 of 213
#
#  for classical.00064-snippet-10-10 top match is classical.00064
#
#  classical.00064-snippet-10-10
#
#  81 of 213
#
#  for classical.00064-snippet-10-20 top match is classical.00084
#
#  classical.00064-snippet-10-20
#
#  82 of 213
#
#  for classical.00065-snippet-10-0 top match is classical.00017
#
#  classical.00065-snippet-10-0
#
#  83 of 213
#
#  for classical.00065-snippet-10-10 top match is classical.00072
#
#  classical.00065-snippet-10-10
#
#  84 of 213
#
#  for classical.00065-snippet-10-20 top match is pop.00040
#
#  classical.00065-snippet-10-20
#
#  85 of 213
#
#  for classical.00069-snippet-10-0 top match is classical.00065
#
#  classical.00069-snippet-10-0
#
#  86 of 213
#
#  for classical.00069-snippet-10-10 top match is classical.00009
#
#  classical.00069-snippet-10-10
#
#  87 of 213
#
#  for classical.00069-snippet-10-20 top match is classical.00007
#
#  classical.00069-snippet-10-20
#
#  88 of 213
#
#  for classical.00070-snippet-10-0 top match is classical.00070
#
#  classical.00070-snippet-10-0
#
#  89 of 213
#
#  for classical.00070-snippet-10-10 top match is classical.00070
#
#  classical.00070-snippet-10-10
#
#  90 of 213
#
#  for classical.00070-snippet-10-20 top match is classical.00070
#
#  classical.00070-snippet-10-20
#
#  91 of 213
#
#  for classical.00074-snippet-10-0 top match is classical.00081
#
#  classical.00074-snippet-10-0
#
#  92 of 213
#
#  for classical.00074-snippet-10-10 top match is classical.00042
#
#  classical.00074-snippet-10-10
#
#  93 of 213
#
#  for classical.00074-snippet-10-20 top match is classical.00074
#
#  classical.00074-snippet-10-20
#
#  94 of 213
#
#  for classical.00075-snippet-10-0 top match is pop.00067
#
#  classical.00075-snippet-10-0
#
#  95 of 213
#
#  for classical.00075-snippet-10-10 top match is pop.00045
#
#  classical.00075-snippet-10-10
#
#  96 of 213
#
#  for classical.00075-snippet-10-20 top match is classical.00001
#
#  classical.00075-snippet-10-20
#
#  97 of 213
#
#  for classical.00079-snippet-10-0 top match is classical.00069
#
#  classical.00079-snippet-10-0
#
#  98 of 213
#
#  for classical.00079-snippet-10-10 top match is classical.00001
#
#  classical.00079-snippet-10-10
#
#  99 of 213
#
#  for classical.00079-snippet-10-20 top match is classical.00013
#
#  classical.00079-snippet-10-20
#
#  100 of 213
#
#  for classical.00080-snippet-10-0 top match is classical.00008
#
#  classical.00080-snippet-10-0
#
#  101 of 213
#
#  for classical.00080-snippet-10-10 top match is classical.00063
#
#  classical.00080-snippet-10-10
#
#  102 of 213
#
#  for classical.00080-snippet-10-20 top match is classical.00047
#
#  classical.00080-snippet-10-20
#
#  103 of 213
#
#  for classical.00084-snippet-10-0 top match is classical.00084
#
#  classical.00084-snippet-10-0
#
#  104 of 213
#
#  for classical.00084-snippet-10-10 top match is pop.00047
#
#  classical.00084-snippet-10-10
#
#  105 of 213
#
#  for classical.00084-snippet-10-20 top match is classical.00084
#
#  classical.00084-snippet-10-20
#
#  106 of 213
#
#  for classical.00085-snippet-10-0 top match is classical.00085
#
#  classical.00085-snippet-10-0
#
#  107 of 213
#
#  for classical.00085-snippet-10-10 top match is classical.00085
#
#  classical.00085-snippet-10-10
#
#  108 of 213
#
#  for classical.00085-snippet-10-20 top match is classical.00085
#
#  classical.00085-snippet-10-20
#
#  109 of 213
#
#  for pop.00000-snippet-10-0 top match is pop.00000
#
#  pop.00000-snippet-10-0
#
#  110 of 213
#
#  for pop.00000-snippet-10-10 top match is pop.00000
#
#  pop.00000-snippet-10-10
#
#  111 of 213
#
#  for pop.00000-snippet-10-20 top match is pop.00000
#
#  pop.00000-snippet-10-20
#
#  112 of 213
#
#  for pop.00003-snippet-10-0 top match is pop.00003
#
#  pop.00003-snippet-10-0
#
#  113 of 213
#
#  for pop.00003-snippet-10-10 top match is pop.00003
#
#  pop.00003-snippet-10-10
#
#  114 of 213
#
#  for pop.00003-snippet-10-20 top match is pop.00003
#
#  pop.00003-snippet-10-20
#
#  115 of 213
#
#  for pop.00004-snippet-10-0 top match is pop.00004
#
#  pop.00004-snippet-10-0
#
#  116 of 213
#
#  for pop.00004-snippet-10-10 top match is pop.00004
#
#  pop.00004-snippet-10-10
#
#  117 of 213
#
#  for pop.00005-snippet-10-0 top match is pop.00005
#
#  pop.00005-snippet-10-0
#
#  118 of 213
#
#  for pop.00005-snippet-10-10 top match is pop.00005
#
#  pop.00005-snippet-10-10
#
#  119 of 213
#
#  for pop.00009-snippet-10-0 top match is pop.00009
#
#  pop.00009-snippet-10-0
#
#  120 of 213
#
#  for pop.00009-snippet-10-10 top match is pop.00009
#
#  pop.00009-snippet-10-10
#
#  121 of 213
#
#  for pop.00010-snippet-10-0 top match is pop.00010
#
#  pop.00010-snippet-10-0
#
#  122 of 213
#
#  for pop.00010-snippet-10-10 top match is pop.00010
#
#  pop.00010-snippet-10-10
#
#  123 of 213
#
#  for pop.00010-snippet-10-20 top match is pop.00010
#
#  pop.00010-snippet-10-20
#
#  124 of 213
#
#  for pop.00011-snippet-10-0 top match is pop.00011
#
#  pop.00011-snippet-10-0
#
#  125 of 213
#
#  for pop.00011-snippet-10-10 top match is pop.00011
#
#  pop.00011-snippet-10-10
#
#  126 of 213
#
#  for pop.00011-snippet-10-20 top match is pop.00011
#
#  pop.00011-snippet-10-20
#
#  127 of 213
#
#  for pop.00012-snippet-10-0 top match is pop.00012
#
#  pop.00012-snippet-10-0
#
#  128 of 213
#
#  for pop.00012-snippet-10-10 top match is pop.00012
#
#  pop.00012-snippet-10-10
#
#  129 of 213
#
#  for pop.00012-snippet-10-20 top match is pop.00012
#
#  pop.00012-snippet-10-20
#
#  130 of 213
#
#  for pop.00013-snippet-10-0 top match is pop.00013
#
#  pop.00013-snippet-10-0
#
#  131 of 213
#
#  for pop.00013-snippet-10-10 top match is pop.00013
#
#  pop.00013-snippet-10-10
#
#  132 of 213
#
#  for pop.00013-snippet-10-20 top match is pop.00013
#
#  pop.00013-snippet-10-20
#
#  133 of 213
#
#  for pop.00014-snippet-10-0 top match is pop.00014
#
#  pop.00014-snippet-10-0
#
#  134 of 213
#
#  for pop.00014-snippet-10-10 top match is pop.00014
#
#  pop.00014-snippet-10-10
#
#  135 of 213
#
#  for pop.00014-snippet-10-20 top match is pop.00014
#
#  pop.00014-snippet-10-20
#
#  136 of 213
#
#  for pop.00015-snippet-10-0 top match is pop.00015
#
#  pop.00015-snippet-10-0
#
#  137 of 213
#
#  for pop.00015-snippet-10-10 top match is pop.00015
#
#  pop.00015-snippet-10-10
#
#  138 of 213
#
#  for pop.00015-snippet-10-20 top match is pop.00015
#
#  pop.00015-snippet-10-20
#
#  139 of 213
#
#  for pop.00019-snippet-10-0 top match is pop.00019
#
#  pop.00019-snippet-10-0
#
#  140 of 213
#
#  for pop.00019-snippet-10-10 top match is pop.00019
#
#  pop.00019-snippet-10-10
#
#  141 of 213
#
#  for pop.00019-snippet-10-20 top match is pop.00019
#
#  pop.00019-snippet-10-20
#
#  142 of 213
#
#  for pop.00020-snippet-10-0 top match is pop.00020
#
#  pop.00020-snippet-10-0
#
#  143 of 213
#
#  for pop.00020-snippet-10-10 top match is pop.00020
#
#  pop.00020-snippet-10-10
#
#  144 of 213
#
#  for pop.00020-snippet-10-20 top match is pop.00020
#
#  pop.00020-snippet-10-20
#
#  145 of 213
#
#  for pop.00024-snippet-10-0 top match is pop.00024
#
#  pop.00024-snippet-10-0
#
#  146 of 213
#
#  for pop.00024-snippet-10-10 top match is pop.00024
#
#  pop.00024-snippet-10-10
#
#  147 of 213
#
#  for pop.00025-snippet-10-0 top match is pop.00025
#
#  pop.00025-snippet-10-0
#
#  148 of 213
#
#  for pop.00025-snippet-10-10 top match is pop.00025
#
#  pop.00025-snippet-10-10
#
#  149 of 213
#
#  for pop.00025-snippet-10-20 top match is pop.00025
#
#  pop.00025-snippet-10-20
#
#  150 of 213
#
#  for pop.00034-snippet-10-0 top match is pop.00034
#
#  pop.00034-snippet-10-0
#
#  151 of 213
#
#  for pop.00034-snippet-10-10 top match is pop.00034
#
#  pop.00034-snippet-10-10
#
#  152 of 213
#
#  for pop.00034-snippet-10-20 top match is pop.00034
#
#  pop.00034-snippet-10-20
#
#  153 of 213
#
#  for pop.00035-snippet-10-0 top match is pop.00035
#
#  pop.00035-snippet-10-0
#
#  154 of 213
#
#  for pop.00035-snippet-10-10 top match is pop.00035
#
#  pop.00035-snippet-10-10
#
#  155 of 213
#
#  for pop.00035-snippet-10-20 top match is pop.00035
#
#  pop.00035-snippet-10-20
#
#  156 of 213
#
#  for pop.00039-snippet-10-0 top match is pop.00039
#
#  pop.00039-snippet-10-0
#
#  157 of 213
#
#  for pop.00039-snippet-10-10 top match is pop.00039
#
#  pop.00039-snippet-10-10
#
#  158 of 213
#
#  for pop.00039-snippet-10-20 top match is pop.00039
#
#  pop.00039-snippet-10-20
#
#  159 of 213
#
#  for pop.00040-snippet-10-0 top match is pop.00040
#
#  pop.00040-snippet-10-0
#
#  160 of 213
#
#  for pop.00040-snippet-10-10 top match is pop.00040
#
#  pop.00040-snippet-10-10
#
#  161 of 213
#
#  for pop.00044-snippet-10-0 top match is pop.00044
#
#  pop.00044-snippet-10-0
#
#  162 of 213
#
#  for pop.00044-snippet-10-10 top match is pop.00044
#
#  pop.00044-snippet-10-10
#
#  163 of 213
#
#  for pop.00044-snippet-10-20 top match is pop.00044
#
#  pop.00044-snippet-10-20
#
#  164 of 213
#
#  for pop.00045-snippet-10-0 top match is pop.00045
#
#  pop.00045-snippet-10-0
#
#  165 of 213
#
#  for pop.00045-snippet-10-10 top match is pop.00045
#
#  pop.00045-snippet-10-10
#
#  166 of 213
#
#  for pop.00045-snippet-10-20 top match is pop.00045
#
#  pop.00045-snippet-10-20
#
#  167 of 213
#
#  for pop.00049-snippet-10-0 top match is pop.00049
#
#  pop.00049-snippet-10-0
#
#  168 of 213
#
#  for pop.00049-snippet-10-10 top match is pop.00049
#
#  pop.00049-snippet-10-10
#
#  169 of 213
#
#  for pop.00049-snippet-10-20 top match is pop.00049
#
#  pop.00049-snippet-10-20
#
#  170 of 213
#
#  for pop.00050-snippet-10-0 top match is pop.00050
#
#  pop.00050-snippet-10-0
#
#  171 of 213
#
#  for pop.00050-snippet-10-10 top match is pop.00050
#
#  pop.00050-snippet-10-10
#
#  172 of 213
#
#  for pop.00050-snippet-10-20 top match is pop.00050
#
#  pop.00050-snippet-10-20
#
#  173 of 213
#
#  for pop.00054-snippet-10-0 top match is pop.00054
#
#  pop.00054-snippet-10-0
#
#  174 of 213
#
#  for pop.00054-snippet-10-10 top match is pop.00054
#
#  pop.00054-snippet-10-10
#
#  175 of 213
#
#  for pop.00054-snippet-10-20 top match is pop.00054
#
#  pop.00054-snippet-10-20
#
#  176 of 213
#
#  for pop.00055-snippet-10-0 top match is pop.00055
#
#  pop.00055-snippet-10-0
#
#  177 of 213
#
#  for pop.00055-snippet-10-10 top match is pop.00055
#
#  pop.00055-snippet-10-10
#
#  178 of 213
#
#  for pop.00055-snippet-10-20 top match is pop.00055
#
#  pop.00055-snippet-10-20
#
#  179 of 213
#
#  for pop.00059-snippet-10-0 top match is pop.00059
#
#  pop.00059-snippet-10-0
#
#  180 of 213
#
#  for pop.00059-snippet-10-10 top match is pop.00059
#
#  pop.00059-snippet-10-10
#
#  181 of 213
#
#  for pop.00059-snippet-10-20 top match is pop.00059
#
#  pop.00059-snippet-10-20
#
#  182 of 213
#
#  for pop.00060-snippet-10-0 top match is pop.00054
#
#  pop.00060-snippet-10-0
#
#  183 of 213
#
#  for pop.00060-snippet-10-10 top match is pop.00054
#
#  pop.00060-snippet-10-10
#
#  184 of 213
#
#  for pop.00060-snippet-10-20 top match is pop.00054
#
#  pop.00060-snippet-10-20
#
#  185 of 213
#
#  for pop.00064-snippet-10-0 top match is pop.00064
#
#  pop.00064-snippet-10-0
#
#  186 of 213
#
#  for pop.00064-snippet-10-10 top match is pop.00064
#
#  pop.00064-snippet-10-10
#
#  187 of 213
#
#  for pop.00064-snippet-10-20 top match is pop.00064
#
#  pop.00064-snippet-10-20
#
#  188 of 213
#
#  for pop.00065-snippet-10-0 top match is pop.00065
#
#  pop.00065-snippet-10-0
#
#  189 of 213
#
#  for pop.00065-snippet-10-10 top match is pop.00065
#
#  pop.00065-snippet-10-10
#
#  190 of 213
#
#  for pop.00065-snippet-10-20 top match is pop.00065
#
#  pop.00065-snippet-10-20
#
#  191 of 213
#
#  for pop.00069-snippet-10-0 top match is pop.00069
#
#  pop.00069-snippet-10-0
#
#  192 of 213
#
#  for pop.00069-snippet-10-10 top match is pop.00069
#
#  pop.00069-snippet-10-10
#
#  193 of 213
#
#  for pop.00069-snippet-10-20 top match is pop.00069
#
#  pop.00069-snippet-10-20
#
#  194 of 213
#
#  for pop.00070-snippet-10-0 top match is pop.00070
#
#  pop.00070-snippet-10-0
#
#  195 of 213
#
#  for pop.00070-snippet-10-10 top match is pop.00070
#
#  pop.00070-snippet-10-10
#
#  196 of 213
#
#  for pop.00070-snippet-10-20 top match is pop.00070
#
#  pop.00070-snippet-10-20
#
#  197 of 213
#
#  for pop.00074-snippet-10-0 top match is pop.00074
#
#  pop.00074-snippet-10-0
#
#  198 of 213
#
#  for pop.00074-snippet-10-10 top match is pop.00074
#
#  pop.00074-snippet-10-10
#
#  199 of 213
#
#  for pop.00074-snippet-10-20 top match is pop.00074
#
#  pop.00074-snippet-10-20
#
#  200 of 213
#
#  for pop.00075-snippet-10-0 top match is pop.00075
#
#  pop.00075-snippet-10-0
#
#  201 of 213
#
#  for pop.00075-snippet-10-10 top match is pop.00075
#
#  pop.00075-snippet-10-10
#
#  202 of 213
#
#  for pop.00075-snippet-10-20 top match is pop.00075
#
#  pop.00075-snippet-10-20
#
#  203 of 213
#
#  for pop.00079-snippet-10-0 top match is classical.00031
#
#  pop.00079-snippet-10-0
#
#  204 of 213
#
#  for pop.00079-snippet-10-10 top match is pop.00079
#
#  pop.00079-snippet-10-10
#
#  205 of 213
#
#  for pop.00079-snippet-10-20 top match is pop.00079
#
#  pop.00079-snippet-10-20
#
#  206 of 213
#
#  for pop.00080-snippet-10-0 top match is pop.00047
#
#  pop.00080-snippet-10-0
#
#  207 of 213
#
#  for pop.00080-snippet-10-10 top match is pop.00080
#
#  pop.00080-snippet-10-10
#
#  208 of 213
#
#  for pop.00080-snippet-10-20 top match is pop.00047
#
#  pop.00080-snippet-10-20
#
#  209 of 213
#
#  for pop.00084-snippet-10-0 top match is pop.00084
#
#  pop.00084-snippet-10-0
#
#  210 of 213
#
#  for pop.00084-snippet-10-10 top match is pop.00084
#
#  pop.00084-snippet-10-10
#
#  211 of 213
#
#  for pop.00085-snippet-10-0 top match is pop.00085
#
#  pop.00085-snippet-10-0
#
#  212 of 213
#
#  for pop.00085-snippet-10-10 top match is pop.00085
#
#  pop.00085-snippet-10-10
#
#  213 of 213
#
#  for pop.00085-snippet-10-20 top match is pop.00085
#
#  pop.00085-snippet-10-20
# Accuracy of the system (in %):  <function accuracy at 0x7fb603fb5f70>

# %%
print("Accuracy of the system (in %): ", accuracy_)
# Out:
# Accuracy of the system (in %):  81.2206572769953

# %%
query_files = (glob.glob(os.path.join(query, "*.wav")))

# %%
#Checking accuracy on a test query set of 10 examples for different n_fft values
query_files = (glob.glob(os.path.join(query, "*.wav")))

#type(query_files)
test_qf = []
test_qf = random.choices(query_files,k=25)
#print(test_qf)

# %%
#Accuracy for n_fft =2048
accuracy_ = accuracy(test_qf)
print("Accuracy for n_fft = 2048: ", accuracy_)
# Out:
#  1 of 25
#
#  for pop.00003-snippet-10-0 top match is classical.00018
#
#  2 of 25
#
#  for classical.00003-snippet-10-20 top match is classical.00007
#
#  3 of 25
#
#  for pop.00011-snippet-10-10 top match is None
#
#  4 of 25
#
#  for classical.00013-snippet-10-0 top match is classical.00083
#
#  5 of 25
#
#  for pop.00020-snippet-10-0 top match is pop.00045
#
#  6 of 25
#
#  for classical.00020-snippet-10-10 top match is classical.00010
#
#  7 of 25
#
#  for pop.00045-snippet-10-10 top match is None
#
#  8 of 25
#
#  for pop.00084-snippet-10-0 top match is classical.00001
#
#  9 of 25
#
#  for pop.00039-snippet-10-0 top match is None
#
#  10 of 25
#
#  for classical.00039-snippet-10-10 top match is classical.00022
#
#  11 of 25
# No hashes found. classical.00000-snippet-10-0
#
#  for classical.00000-snippet-10-0 top match is None
#
#  12 of 25
#
#  for pop.00075-snippet-10-0 top match is None
#
#  13 of 25
#
#  for classical.00075-snippet-10-0 top match is classical.00084
#
#  14 of 25
#
#  for classical.00085-snippet-10-10 top match is None
#
#  15 of 25
#
#  for pop.00019-snippet-10-0 top match is None
#
#  16 of 25
#
#  for classical.00084-snippet-10-20 top match is None
#
#  17 of 25
#
#  for classical.00054-snippet-10-0 top match is None
#
#  18 of 25
#
#  for classical.00009-snippet-10-20 top match is classical.00059
#
#  19 of 25
#
#  for classical.00085-snippet-10-20 top match is classical.00063
#
#  20 of 25
#
#  for pop.00000-snippet-10-10 top match is None
#
#  21 of 25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-174-7fd3e98a5b8d> in <module>
#       1 #Accuracy for n_fft =2048
# ----> 2 accuracy_ = accuracy(test_qf)
#       3 print("Accuracy for n_fft = 2048: ", accuracy_)
#
# <ipython-input-171-cd29db76dee8> in accuracy(query_files)
#      12         progress += 1
#      13         print ("\n %s of %s "%(progress,total_queries))
# ---> 14         top_match = top_match_(audio_file)
#      15
#      16         # get the ground truth song id
#
# <ipython-input-170-403a02a7721d> in top_match_(q_audio)
#       3     q_audio : str
#       4 ):
# ----> 5     matches = audioid(q_audio)
#       6     max_val = 0
#       7     max_key = None
#
# <ipython-input-126-a31abf6cb2a6> in audioid(query_audio, fingerprint_database, n_fft, max_peaks)
#      11 #load back the fingerprints for the database
#      12     with open(fingerprint_database, 'rb') as f:
# ---> 13         db_fingerprints = pickle.load(f)
#      14
#      15     query_match = [] # we will store all matches here
#
# KeyboardInterrupt:

# %%
#debug code

qaudio_file = database + 'classical.00000.wav'
#peaks = peak_picking(audio_file)
#print(peaks)
#type(peaks)
#peaks.shape
#hash = generate_hashes(audio_file)
matches = audioid(qaudio_file)
print(matches)
type(matches)
len(matches)
#type(hash)
# len(hash)
#print(hash)
#matches = audioid(qaudio_file)
#matches = [(db_song_id, score) for db_song_id, score in matches.items()]
# matches = sorted(matches, key=lambda a: a[1], reverse=True)
# print("\nsorted \n" ,matches)
# Out:
#  generating query hashes..
# Finding matches...
# [{'classical.00000': 14640, 'classical.00001': 1, 'classical.00002': 3, 'classical.00003': 1, 'classical.00004': 1, 'classical.00005': 1, 'classical.00006': 1, 'classical.00007': 1, 'classical.00008': 1, 'classical.00009': 2, 'classical.00010': 1, 'classical.00011': 1, 'classical.00012': 1, 'classical.00013': 2, 'classical.00014': 1, 'classical.00015': 1, 'classical.00016': 1, 'classical.00017': 3, 'classical.00018': 1, 'classical.00019': 1, 'classical.00020': 1, 'classical.00021': 1, 'classical.00022': 3, 'classical.00023': 1, 'classical.00024': 1, 'classical.00025': 2, 'classical.00026': 1, 'classical.00027': 1, 'classical.00028': 1, 'classical.00029': 3, 'classical.00030': 1, 'classical.00031': 1, 'classical.00032': 1, 'classical.00033': 2, 'classical.00034': 1, 'classical.00035': 1, 'classical.00036': 1, 'classical.00037': 1, 'classical.00038': 1, 'classical.00039': 1, 'classical.00040': 1, 'classical.00041': 1, 'classical.00042': 2, 'classical.00044': 1, 'classical.00045': 1, 'classical.00046': 1, 'classical.00047': 1, 'classical.00048': 1, 'classical.00049': 1, 'classical.00050': 1, 'classical.00051': 1, 'classical.00052': 1, 'classical.00053': 3, 'classical.00054': 1, 'classical.00055': 1, 'classical.00056': 1, 'classical.00057': 1, 'classical.00058': 1, 'classical.00059': 1, 'classical.00060': 1, 'classical.00061': 1, 'classical.00062': 1, 'classical.00063': 1, 'classical.00064': 1, 'classical.00065': 1, 'classical.00066': 1, 'classical.00067': 1, 'classical.00068': 1, 'classical.00069': 2, 'classical.00070': 1, 'classical.00071': 1, 'classical.00072': 1, 'classical.00073': 1, 'classical.00074': 1, 'classical.00075': 1, 'classical.00076': 1, 'classical.00077': 1, 'classical.00078': 1, 'classical.00079': 1, 'classical.00080': 1, 'classical.00081': 1, 'classical.00082': 1, 'classical.00083': 1, 'classical.00084': 1, 'classical.00085': 1, 'classical.00086': 1, 'classical.00087': 1, 'classical.00088': 1, 'classical.00089': 2, 'classical.00090': 1, 'classical.00091': 1, 'classical.00092': 3, 'classical.00093': 1, 'classical.00094': 1, 'classical.00095': 1, 'classical.00096': 1, 'classical.00097': 1, 'classical.00098': 2, 'classical.00099': 1, 'pop.00000': 1, 'pop.00001': 1, 'pop.00002': 1, 'pop.00003': 1, 'pop.00004': 1, 'pop.00005': 1, 'pop.00006': 1, 'pop.00007': 1, 'pop.00008': 1, 'pop.00009': 1, 'pop.00010': 1, 'pop.00011': 1, 'pop.00012': 1, 'pop.00013': 1, 'pop.00014': 1, 'pop.00015': 1, 'pop.00016': 1, 'pop.00017': 1, 'pop.00018': 1, 'pop.00019': 3, 'pop.00020': 1, 'pop.00021': 1, 'pop.00022': 1, 'pop.00023': 1, 'pop.00024': 2, 'pop.00025': 1, 'pop.00027': 2, 'pop.00028': 1, 'pop.00029': 1, 'pop.00030': 1, 'pop.00031': 1, 'pop.00032': 1, 'pop.00033': 1, 'pop.00034': 1, 'pop.00035': 1, 'pop.00036': 1, 'pop.00037': 1, 'pop.00038': 2, 'pop.00039': 1, 'pop.00040': 1, 'pop.00041': 1, 'pop.00042': 1, 'pop.00044': 1, 'pop.00045': 1, 'pop.00046': 1, 'pop.00047': 2, 'pop.00048': 1, 'pop.00049': 1, 'pop.00050': 1, 'pop.00051': 1, 'pop.00052': 1, 'pop.00053': 1, 'pop.00054': 1, 'pop.00055': 1, 'pop.00056': 2, 'pop.00057': 1, 'pop.00058': 1, 'pop.00059': 1, 'pop.00060': 1, 'pop.00061': 1, 'pop.00062': 1, 'pop.00063': 1, 'pop.00064': 1, 'pop.00065': 1, 'pop.00066': 1, 'pop.00067': 1, 'pop.00068': 1, 'pop.00069': 1, 'pop.00070': 1, 'pop.00071': 1, 'pop.00072': 1, 'pop.00073': 1, 'pop.00074': 1, 'pop.00075': 1, 'pop.00076': 1, 'pop.00078': 1, 'pop.00079': 1, 'pop.00080': 1, 'pop.00082': 1, 'pop.00083': 1, 'pop.00084': 1, 'pop.00085': 1, 'pop.00086': 1, 'pop.00087': 1, 'pop.00088': 1, 'pop.00089': 1, 'pop.00090': 1, 'pop.00091': 1, 'pop.00092': 1, 'pop.00093': 1, 'pop.00094': 1, 'pop.00095': 1, 'pop.00096': 1, 'pop.00097': 1, 'pop.00098': 1, 'pop.00099': 1}]
# 1

# %%
print(type(matches))
#print(matches[0])
max_val = 0
max_key = None
for k in matches[0].keys():
    #print(matches[0][k])
    if max_val < matches[0][k]:

        max_key = k
        max_val = matches[0][k]

print(max_key, max_val)
# Out:
# <class 'list'>
# classical.00000 14640
